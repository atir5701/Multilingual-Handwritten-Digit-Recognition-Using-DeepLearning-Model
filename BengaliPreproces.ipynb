# %%
import os
from os import listdir
import numpy as np

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.5.5

# %%
IMG_WIDTH=32
IMG_HEIGHT=32

img_folder=r'E:\Sem-6\Digit_Recognition_Project\Bengali\0'

for file in os.listdir(img_folder):
    image_path=os.path.join(img_folder,file)
    image=cv2.imread(image_path)
    new_image = cv2.resize(image,(IMG_HEIGHT, IMG_WIDTH))
    image = np.array(new_image)
    image=np.invert(image)
    image = image.astype('float32')
    image /= 255
    #path = 'E:\Sem-6\Digit_Recognition_Project\Bengali_Processes'
    #cv2.imwrite(path+'\\'+file, image*255)
# Out:
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_14_BOG_1_317.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_22_Farid_3_318.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_319.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_320.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_321.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_322.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_323.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_11_1_324.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_12_1_325.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_12_1_87.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_13_1_326.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_13_1_88.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_14_1_327.jpg
# E:\Sem-6\Digit_Recognition_Project\Bengali\0\1_B.BARIA_1_1_328.jpg
# ...

# %%
img_folder=r'E:\Sem-6\Digit_Recognition_Project\Bengali\0'

for file in os.listdir(img_folder):
    print(file)
# Out:
# 1_14_BOG_1_317.jpg
# 1_22_Farid_3_318.jpg
# 1_B.BARIA_11_1_319.jpg
# 1_B.BARIA_11_1_320.jpg
# 1_B.BARIA_11_1_321.jpg
# 1_B.BARIA_11_1_322.jpg
# 1_B.BARIA_11_1_323.jpg
# 1_B.BARIA_11_1_324.jpg
# 1_B.BARIA_12_1_325.jpg
# 1_B.BARIA_12_1_87.jpg
# 1_B.BARIA_13_1_326.jpg
# 1_B.BARIA_13_1_88.jpg
# 1_B.BARIA_14_1_327.jpg
# 1_B.BARIA_1_1_328.jpg
# 1_B.baria_22_3_00039.jpg
# 1_B.BARIA_22_3_329.jpg
# 1_B.baria_25_3_00084.jpg
# 1_B.BARI_13_1_330.jpg
# 1_B.BARI_14_331.jpg
# 1_BAG_11_1_332.jpg
# 1_BAG_11_1_333.jpg
# 1_BAG_11_1_334.jpg
# 1_BAG_11_1_335.jpg
# 1_BAG_11_1_336.jpg
# 1_BAG_12_1_337.jpg
# 1_BAG_12_1_338.jpg
# 1_BARG_11_1_339.jpg
# 1_BAR_10_1_340.jpg
# 1_BAR_11_1_341.jpg
# 1_BAR_11_1_342.jpg
# 1_BAR_11_1_343.jpg
# 1_BAR_11_1_344.jpg
# 1_BAR_11_1_345.jpg
# 1_BAR_11_1_346.jpg
# 1_BAR_11_1_347.jpg
# 1_BAR_11_1_348.jpg
# 1_BAR_11_1_349.jpg
# 1_BAR_11_1_350.jpg
# 1_BAR_11_1_351.jpg
# 1_BAR_11_1_352.jpg
# 1_BAR_11_1_353.jpg
# 1_BAR_11_1_354.jpg
# 1_BAR_11_1_355.jpg
# 1_BAR_11_1_356.jpg
# ...
